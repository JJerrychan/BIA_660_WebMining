# %% [markdown]
# # <center>Web Scraping by API </center>

# %% [markdown]
# ## 1. Scrape data through APIs
# - Online content providers usually provide APIs for you to access data. Two types of APIs:
#    * Python packages: e.g. tweepy package from Twitter
#    * REST APIs: e.g. OMDB APIs (http://www.omdbapi.com), or TMDB (https://developers.themoviedb.org/3/getting-started)
# - You need to read documentation of APIs to figure out how to access data

# %% [markdown]
# ## 2. Scrape data by REST APIs (e.g. OMDB API)
# - A REST API is a web service that uses `HTTP` requests to `GET`, `PUT`, `POST` and `DELETE` data
# - Example:
#     - https://groceries.asda.com/api/items/search<font color="blue"><b>?</b></font><font color='green'><b>keyword</b></font>=<font color='red'><b>yogurt<b></font><front color='purple'><b>&</b></font><font color='green'><b>r</b></font>=<font color='red'><b>json<b></font>, where
#         - `?`: separate API endpoint  `https://groceries.asda.com/api/items/search` from parameters
#         - `keyword=yogurt`: search `yogurt` on parameter `keyword`
#         - `&`: combine multiple search criteria
#         - `r=json`: result is in json format
#     - You can directly paste the above API to your browser
#     - Or issue API calls using requests
# - You need to read API documentation to understand how to specify parameters

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import requests
import json
import pandas as pd

# %%
import requests
import json

keyword = 'yogurt'


url="https://groceries.asda.com/api/items/search?keyword=" + keyword + "&r=json"

print(url)

# invoke the API 
r = requests.get(url)

# if the API call returns a successful response
if r.status_code==200:
    
    # This API call returns a json object
    # r.json() gives the json object
    # json. dumps() function converts a Python object into a json string
    result = r.json()
    print (json.dumps(result, indent=4))
# Out:
# https://groceries.asda.com/api/items/search?keyword=yogurt&r=json
# {
#     "statusMessage": "The API Item Search was executed successfully",
#     "errors": [],
#     "keyword": "yogurt",
#     "storeId": "4565",
#     "autoCorrectedTerm": "",
#     "didYouMeanTerm": "",
#     "isHookLogicInsert": "false",
#     "totalResult": "447",
#     "currentPage": "1",
#     "resultsStartIndex": "1",
#     "resultsEndIndex": "60",
#     "maxPages": "8",
#     "qusApplied": false,
#     "productBoostingDetails": "0^rule_613f0638f04fd127608474cd^^^Disabled",
#     "monetizedItems": [],
#     "items": [
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368400",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "14",
#             "asdaSuggest": "",
#             "itemName": "Corner Vanilla Yogurt with Chocolate Balls",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031656",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "124g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277031",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6429",
#             "name": "Muller Corner Vanilla Yogurt with Chocolate Balls",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031656",
#             "pricePerUOM": "",
#             "searchTuningScore": "8717191.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368402",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Corner Banana Yogurt with Chocolate Flakes",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031660",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "124g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277055",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.8889",
#             "name": "Muller Corner Banana Yogurt with Chocolate Flakes",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031660",
#             "pricePerUOM": "",
#             "searchTuningScore": "5447849.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368406",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Corner Toffee Yogurt with Chocolate Hoops",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031761",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "124g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277116",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5556",
#             "name": "Muller Corner Toffee Yogurt with Chocolate Hoops",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031761",
#             "pricePerUOM": "",
#             "searchTuningScore": "5098466.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368408",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "14",
#             "asdaSuggest": "",
#             "itemName": "Corner Strawberry Yogurt",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031677",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "136g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277239",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.9286",
#             "name": "Muller Corner Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031677",
#             "pricePerUOM": "",
#             "searchTuningScore": "4553693.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346362",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "25",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Toffee Yogurt",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808315",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243579",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.52",
#             "name": "Muller Light Fat Free Toffee Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808315",
#             "pricePerUOM": "",
#             "searchTuningScore": "3162789.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6202233",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "45",
#             "asdaSuggest": "",
#             "itemName": "Vanilla & Granola Breakfast Pot low fat yoghurt",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078311452",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "165g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "5060360502960",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3778",
#             "name": "Activia Vanilla & Granola Breakfast Pot low fat yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078311452",
#             "pricePerUOM": "",
#             "searchTuningScore": "2555478.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346360",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "21",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Banana and Custard Yogurt",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808339",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243555",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2381",
#             "name": "Muller Light Fat Free Banana and Custard Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808339",
#             "pricePerUOM": "",
#             "searchTuningScore": "2402035.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4786440",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "54",
#             "asdaSuggest": "",
#             "itemName": "Apricot, Strawberry & Raspberry Yogurt",
#             "price": "\u00a32.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001458433",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Petits Filous",
#             "promoType": "Rollback",
#             "weight": "18x47g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770051621",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4815",
#             "name": "Petits Filous Apricot, Strawberry & Raspberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001458433",
#             "pricePerUOM": "",
#             "searchTuningScore": "2202921.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "3::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7367121",
#             "promoDetailFull": "3 for \u00a32",
#             "availability": "A",
#             "totalReviewCount": "5",
#             "asdaSuggest": "",
#             "itemName": "Dairy Milk Buttons Chocolate Dessert",
#             "price": "\u00a30.75",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000376780232",
#             "promoId": "ls91552",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Cadbury",
#             "promoType": "No Promo",
#             "weight": "75g       ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "3",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "4025500278366",
#             "promoDetail": "3 for \u00a32",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.8",
#             "name": "Cadbury Dairy Milk Buttons Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000376780232",
#             "pricePerUOM": "",
#             "searchTuningScore": "2164674.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006862",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "99",
#             "asdaSuggest": "",
#             "itemName": "Mango, Strawberry, Kiwi & Apricot Multipack Yoghurt",
#             "price": "\u00a32.85",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290068605",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "8x115g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506104",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5758",
#             "name": "Activia Mango, Strawberry, Kiwi & Apricot Multipack Yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290068605",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.232283",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 5
#         },
#         {
#             "shelfId": "1215639169975",
#             "shelfName": "Probiotic, Health & Kefir Drinks",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "2396629",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "174",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Cultured Yoghurt Drink",
#             "price": "\u00a33.25",
#             "imageURL": "",
#             "aisleName": "Healthy Yogurt Drinks",
#             "id": "71431377",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.85",
#             "brandName": "Actimel",
#             "promoType": "Rollback",
#             "weight": "12x100    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060058330868",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5805",
#             "name": "Actimel Strawberry Cultured Yoghurt Drink",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=71431377",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.115686",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 8
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582592",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "24",
#             "asdaSuggest": "",
#             "itemName": "Cherry Intensely Creamy Yoghurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285443",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x110g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500027",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.375",
#             "name": "Activia Cherry Intensely Creamy Yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285443",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.106691",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 4
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582588",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "60",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Intensely Creamy Yoghurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285499",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x110g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500003",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4333",
#             "name": "Activia Strawberry Intensely Creamy Yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285499",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.096563",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 5
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582596",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "64",
#             "asdaSuggest": "",
#             "itemName": "Peach Intensely Creamy Yoghurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285082",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x110g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500041",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.75",
#             "name": "Activia Peach Intensely Creamy Yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285082",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.077023",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 9
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346374",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "39",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Limited Edition Yogurt",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808405",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243715",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "2.7949",
#             "name": "Muller Light Fat Free Limited Edition Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808405",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.075933",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -3
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368412",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "15",
#             "asdaSuggest": "",
#             "itemName": "Corner Vanilla Chocolate Balls and Banana Chocolate Flakes Yogurts",
#             "price": "\u00a32.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031669",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Muller",
#             "promoType": "Rollback",
#             "weight": "6x124g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277482",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6667",
#             "name": "Muller Corner Vanilla Chocolate Balls and Banana Chocolate Flakes Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031669",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.075738",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -6
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006858",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "21",
#             "asdaSuggest": "",
#             "itemName": "Strawberry, Raspberry, Cherry & Blueberry No Added Sugar Fat Free Multipack yoghurt",
#             "price": "\u00a32.85",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290067947",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "8x115g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506388",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.9048",
#             "name": "Activia Strawberry, Raspberry, Cherry & Blueberry No Added Sugar Fat Free Multipack yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290067947",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.075544",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 11
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346354",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "19",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Strawberry Yogurt",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808369",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243357",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7368",
#             "name": "Muller Light Fat Free Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808369",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.070574",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -5
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "3::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7367127",
#             "promoDetailFull": "3 for \u00a32",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Chocolate Dessert Limited Edition",
#             "price": "\u00a30.75",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000376780316",
#             "promoId": "ls91552",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Cadbury",
#             "promoType": "No Promo",
#             "weight": "75g       ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "3",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "4025500278427",
#             "promoDetail": "3 for \u00a32",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.0",
#             "name": "Cadbury Chocolate Dessert Limited Edition",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000376780316",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.070406",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -8
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "3::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7367119",
#             "promoDetailFull": "3 for \u00a32",
#             "availability": "A",
#             "totalReviewCount": "7",
#             "asdaSuggest": "",
#             "itemName": "Flake Chocolate Dessert",
#             "price": "\u00a30.75",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000376780395",
#             "promoId": "ls91552",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Cadbury",
#             "promoType": "No Promo",
#             "weight": "75g       ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "3",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "4025500278342",
#             "promoDetail": "3 for \u00a32",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4286",
#             "name": "Cadbury Flake Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000376780395",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.060513",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -6
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6506041",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "33",
#             "asdaSuggest": "",
#             "itemName": "Salted Caramel Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000159248742",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Arla Protein",
#             "promoType": "No Promo",
#             "weight": "200g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "6413300024357",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "2.8788",
#             "name": "Arla Protein Salted Caramel Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000159248742",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.056244",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -1
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368410",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "11",
#             "asdaSuggest": "",
#             "itemName": "Corner Strawberry and Peach & Apricot Yogurts",
#             "price": "\u00a32.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031678",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Muller",
#             "promoType": "Rollback",
#             "weight": "6x136g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277642",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2727",
#             "name": "Muller Corner Strawberry and Peach & Apricot Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031678",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.053058",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -5
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6744532",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "32",
#             "asdaSuggest": "",
#             "itemName": "Milk Chocolate & Toffee Dessert",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000226920906",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.20",
#             "brandName": "Rolo",
#             "promoType": "Rollback",
#             "weight": "4x65g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290045282",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6875",
#             "name": "Rolo Milk Chocolate & Toffee Dessert",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000226920906",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.052867",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 10
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6744530",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "15",
#             "asdaSuggest": "",
#             "itemName": "White Chocolate Dessert",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000226920902",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.20",
#             "brandName": "Milkybar",
#             "promoType": "Rollback",
#             "weight": "4x65g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290045251",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.9333",
#             "name": "Milkybar White Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000226920902",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.050256",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 11
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6041536",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "33",
#             "asdaSuggest": "",
#             "itemName": "Kvarg Raspberry",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000023135121",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Lindahls",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "3023290018354",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.0",
#             "name": "Lindahls Kvarg Raspberry",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000023135121",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.05",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 4
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6525307",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "34",
#             "asdaSuggest": "",
#             "itemName": "Kvarg White Chocolate",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000164970300",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Lindahls",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "3023290037577",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "2.9118",
# ...
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500278120",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7692",
#             "name": "Muller Rice Vanilla Custard Low Fat Pudding",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031640",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.028489",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -16
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7366589",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "3",
#             "asdaSuggest": "",
#             "itemName": "Little Yeos Organic No Added Sugar Mango, Vanilla and Blueberry, Banana Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000376780465",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.50",
#             "brandName": "Yeo Valley",
#             "promoType": "Rollback",
#             "weight": "6x42g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5036589254553",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "Yeo Valley Little Yeos Organic No Added Sugar Mango, Vanilla and Blueberry, Banana Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600066"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000376780465",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.0277",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -16
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5033894",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "15",
#             "asdaSuggest": "",
#             "itemName": "Raspberry Yogurt",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001813465",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Arla Protein",
#             "promoType": "No Promo",
#             "weight": "200g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "6413300018035",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.9333",
#             "name": "Arla Protein Raspberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "49100001"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001813465",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.024451",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6677300",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "16",
#             "asdaSuggest": "",
#             "itemName": "Skyr Icelandic Style Salted Caramel Flavour Yogurt",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000206330981",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "4025500253707",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3125",
#             "name": "Muller Light Skyr Icelandic Style Salted Caramel Flavour Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000206330981",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.023887",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 2
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7296508",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Pro + Kvarg Banoffee Pie",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000359006880",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Lindahls",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "3023290062777",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.75",
#             "name": "Lindahls Pro + Kvarg Banoffee Pie",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000359006880",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.022877",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -8
#         },
#         {
#             "shelfId": "1215286439451",
#             "shelfName": "Natural & Greek",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7290720",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "15",
#             "asdaSuggest": "",
#             "itemName": "Total 0% Fat Greek Recipe Strained Yogurt",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000357303731",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Fage",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "5201054017012",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.9333",
#             "name": "Fage Total 0% Fat Greek Recipe Strained Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000357303731",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.020268",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -1
#         },
#         {
#             "shelfId": "1215286439451",
#             "shelfName": "Natural & Greek",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7366587",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "1",
#             "asdaSuggest": "",
#             "itemName": "Organic Natural Creamy Bio Live Yogurt",
#             "price": "\u00a30.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000376780375",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a30.60",
#             "brandName": "Yeo Valley",
#             "promoType": "Rollback",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5014067133804",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "Yeo Valley Organic Natural Creamy Bio Live Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600066"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000376780375",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.019608",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         }
#     ],
#     "facets": [
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Chilled Food",
#             "displayName": "Chilled Food",
#             "itemCount": "377"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Baby, Toddler & Kids",
#             "displayName": "Baby, Toddler & Kids",
#             "itemCount": "17"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Bakery",
#             "displayName": "Bakery",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Free From...",
#             "displayName": "Free From...",
#             "itemCount": "12"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Food Cupboard",
#             "displayName": "Food Cupboard",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Drinks",
#             "displayName": "Drinks",
#             "itemCount": "9"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:World & Local Food",
#             "displayName": "World & Local Food",
#             "itemCount": "5"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Toiletries & Beauty",
#             "displayName": "Toiletries & Beauty",
#             "itemCount": "2"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Meat, Poultry & Fish",
#             "displayName": "Meat, Poultry & Fish",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Pet Food & Accessories",
#             "displayName": "Pet Food & Accessories",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA",
#             "displayName": "ASDA",
#             "itemCount": "60"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller",
#             "displayName": "Muller",
#             "itemCount": "25"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Activia",
#             "displayName": "Activia",
#             "itemCount": "17"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:GU",
#             "displayName": "GU",
#             "itemCount": "16"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Yeo Valley",
#             "displayName": "Yeo Valley",
#             "itemCount": "15"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA Extra Special",
#             "displayName": "ASDA Extra Special",
#             "itemCount": "14"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Lindahls",
#             "displayName": "Lindahls",
#             "itemCount": "14"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Actimel",
#             "displayName": "Actimel",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Cadbury",
#             "displayName": "Cadbury",
#             "itemCount": "11"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Alpro",
#             "displayName": "Alpro",
#             "itemCount": "9"
#         }
#     ],
#     "mediaContent": "",
#     "useKeywordAsIcon": "",
#     "processTime": 69,
#     "statusCode": "0"
# }

# %%
# Exercise 2.2.  Another way to pass parameters

parameters = {'keyword': 'yogurt', 
              'r': 'json'}

r=requests.get('https://groceries.asda.com/api/items/search', params=parameters)

# in case authentication is needed, use
# r = requests.get('https://api.github.com/user', \
# auth=('user', 'pass'))

# if the API call returns a successful response
if r.status_code==200:
    
    # This API call returns a json object
    # r.json() gives the json object
    print (json.dumps(r.json(), indent=4))
# Out:
# {
#     "statusMessage": "The API Item Search was executed successfully",
#     "errors": [],
#     "keyword": "yogurt",
#     "storeId": "4565",
#     "autoCorrectedTerm": "",
#     "didYouMeanTerm": "",
#     "isHookLogicInsert": "false",
#     "totalResult": "447",
#     "currentPage": "1",
#     "resultsStartIndex": "1",
#     "resultsEndIndex": "60",
#     "maxPages": "8",
#     "qusApplied": false,
#     "productBoostingDetails": "0^rule_613f0638f04fd127608474cd^^^Disabled",
#     "monetizedItems": [],
#     "items": [
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368400",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "14",
#             "asdaSuggest": "",
#             "itemName": "Corner Vanilla Yogurt with Chocolate Balls",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031656",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "124g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277031",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6429",
#             "name": "Muller Corner Vanilla Yogurt with Chocolate Balls",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031656",
#             "pricePerUOM": "",
#             "searchTuningScore": "8717191.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368402",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Corner Banana Yogurt with Chocolate Flakes",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031660",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "124g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277055",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.8889",
#             "name": "Muller Corner Banana Yogurt with Chocolate Flakes",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031660",
#             "pricePerUOM": "",
#             "searchTuningScore": "5447849.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368406",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Corner Toffee Yogurt with Chocolate Hoops",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031761",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "124g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277116",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5556",
#             "name": "Muller Corner Toffee Yogurt with Chocolate Hoops",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031761",
#             "pricePerUOM": "",
#             "searchTuningScore": "5098466.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368408",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "14",
#             "asdaSuggest": "",
#             "itemName": "Corner Strawberry Yogurt",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031677",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller",
#             "promoType": "No Promo",
#             "weight": "136g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277239",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.9286",
#             "name": "Muller Corner Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031677",
#             "pricePerUOM": "",
#             "searchTuningScore": "4553693.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346362",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "25",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Toffee Yogurt",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808315",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243579",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.52",
#             "name": "Muller Light Fat Free Toffee Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808315",
#             "pricePerUOM": "",
#             "searchTuningScore": "3162789.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6202233",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "45",
#             "asdaSuggest": "",
#             "itemName": "Vanilla & Granola Breakfast Pot low fat yoghurt",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078311452",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "165g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "5060360502960",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3778",
#             "name": "Activia Vanilla & Granola Breakfast Pot low fat yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078311452",
#             "pricePerUOM": "",
#             "searchTuningScore": "2555478.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346360",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "21",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Banana and Custard Yogurt",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808339",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243555",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2381",
#             "name": "Muller Light Fat Free Banana and Custard Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808339",
#             "pricePerUOM": "",
#             "searchTuningScore": "2402035.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4786440",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "54",
#             "asdaSuggest": "",
#             "itemName": "Apricot, Strawberry & Raspberry Yogurt",
#             "price": "\u00a32.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001458433",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Petits Filous",
#             "promoType": "Rollback",
#             "weight": "18x47g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770051621",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4815",
#             "name": "Petits Filous Apricot, Strawberry & Raspberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001458433",
#             "pricePerUOM": "",
#             "searchTuningScore": "2202921.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "3::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7367121",
#             "promoDetailFull": "3 for \u00a32",
#             "availability": "A",
#             "totalReviewCount": "5",
#             "asdaSuggest": "",
#             "itemName": "Dairy Milk Buttons Chocolate Dessert",
#             "price": "\u00a30.75",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000376780232",
#             "promoId": "ls91552",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Cadbury",
#             "promoType": "No Promo",
#             "weight": "75g       ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "3",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "4025500278366",
#             "promoDetail": "3 for \u00a32",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.8",
#             "name": "Cadbury Dairy Milk Buttons Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000376780232",
#             "pricePerUOM": "",
#             "searchTuningScore": "2164674.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006862",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "99",
#             "asdaSuggest": "",
#             "itemName": "Mango, Strawberry, Kiwi & Apricot Multipack Yoghurt",
#             "price": "\u00a32.85",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290068605",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "8x115g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506104",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5758",
#             "name": "Activia Mango, Strawberry, Kiwi & Apricot Multipack Yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290068605",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.232283",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 5
#         },
#         {
#             "shelfId": "1215639169975",
#             "shelfName": "Probiotic, Health & Kefir Drinks",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "2396629",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "174",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Cultured Yoghurt Drink",
#             "price": "\u00a33.25",
#             "imageURL": "",
#             "aisleName": "Healthy Yogurt Drinks",
#             "id": "71431377",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.85",
#             "brandName": "Actimel",
#             "promoType": "Rollback",
#             "weight": "12x100    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060058330868",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5805",
#             "name": "Actimel Strawberry Cultured Yoghurt Drink",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=71431377",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.120408",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 8
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582592",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "24",
#             "asdaSuggest": "",
#             "itemName": "Cherry Intensely Creamy Yoghurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285443",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x110g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500027",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.375",
#             "name": "Activia Cherry Intensely Creamy Yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285443",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.106691",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 4
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582588",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "60",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Intensely Creamy Yoghurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285499",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x110g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500003",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4333",
#             "name": "Activia Strawberry Intensely Creamy Yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285499",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.096563",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 5
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582596",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "64",
#             "asdaSuggest": "",
#             "itemName": "Peach Intensely Creamy Yoghurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285082",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x110g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500041",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.75",
#             "name": "Activia Peach Intensely Creamy Yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285082",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.077023",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 9
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346374",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "39",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Limited Edition Yogurt",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808405",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243715",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "2.7949",
#             "name": "Muller Light Fat Free Limited Edition Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808405",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.075933",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -3
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368412",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "15",
#             "asdaSuggest": "",
#             "itemName": "Corner Vanilla Chocolate Balls and Banana Chocolate Flakes Yogurts",
#             "price": "\u00a32.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031669",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Muller",
#             "promoType": "Rollback",
#             "weight": "6x124g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277482",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6667",
#             "name": "Muller Corner Vanilla Chocolate Balls and Banana Chocolate Flakes Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031669",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.075738",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -6
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006858",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "21",
#             "asdaSuggest": "",
#             "itemName": "Strawberry, Raspberry, Cherry & Blueberry No Added Sugar Fat Free Multipack yoghurt",
#             "price": "\u00a32.85",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290067947",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "8x115g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506388",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.9048",
#             "name": "Activia Strawberry, Raspberry, Cherry & Blueberry No Added Sugar Fat Free Multipack yoghurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290067947",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.075544",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 11
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346354",
#             "promoDetailFull": "10 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "19",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Strawberry Yogurt",
#             "price": "\u00a30.60",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808369",
#             "promoId": "ls92280",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243357",
#             "promoDetail": "10 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7368",
#             "name": "Muller Light Fat Free Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808369",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.070574",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -5
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "3::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7367127",
#             "promoDetailFull": "3 for \u00a32",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Chocolate Dessert Limited Edition",
#             "price": "\u00a30.75",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000376780316",
#             "promoId": "ls91552",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Cadbury",
#             "promoType": "No Promo",
#             "weight": "75g       ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "3",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "4025500278427",
#             "promoDetail": "3 for \u00a32",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.0",
#             "name": "Cadbury Chocolate Dessert Limited Edition",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000376780316",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.070406",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -8
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "3::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7367119",
#             "promoDetailFull": "3 for \u00a32",
#             "availability": "A",
#             "totalReviewCount": "7",
#             "asdaSuggest": "",
#             "itemName": "Flake Chocolate Dessert",
#             "price": "\u00a30.75",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000376780395",
#             "promoId": "ls91552",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Cadbury",
#             "promoType": "No Promo",
#             "weight": "75g       ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "3",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "4025500278342",
#             "promoDetail": "3 for \u00a32",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4286",
#             "name": "Cadbury Flake Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000376780395",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.060513",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -6
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6506041",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "33",
#             "asdaSuggest": "",
#             "itemName": "Salted Caramel Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000159248742",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Arla Protein",
#             "promoType": "No Promo",
#             "weight": "200g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "6413300024357",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "2.8788",
#             "name": "Arla Protein Salted Caramel Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000159248742",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.056244",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -1
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7368410",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "11",
#             "asdaSuggest": "",
#             "itemName": "Corner Strawberry and Peach & Apricot Yogurts",
#             "price": "\u00a32.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000377031678",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Muller",
#             "promoType": "Rollback",
#             "weight": "6x136g    ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500277642",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2727",
#             "name": "Muller Corner Strawberry and Peach & Apricot Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031678",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.053058",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -5
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6744532",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "32",
#             "asdaSuggest": "",
#             "itemName": "Milk Chocolate & Toffee Dessert",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000226920906",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.20",
#             "brandName": "Rolo",
#             "promoType": "Rollback",
#             "weight": "4x65g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290045282",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6875",
#             "name": "Rolo Milk Chocolate & Toffee Dessert",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000226920906",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.052867",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 10
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6744530",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "15",
#             "asdaSuggest": "",
#             "itemName": "White Chocolate Dessert",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000226920902",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.20",
#             "brandName": "Milkybar",
#             "promoType": "Rollback",
#             "weight": "4x65g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290045251",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.9333",
#             "name": "Milkybar White Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000226920902",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.050256",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 11
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6041536",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "33",
#             "asdaSuggest": "",
#             "itemName": "Kvarg Raspberry",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000023135121",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Lindahls",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "3023290018354",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.0",
#             "name": "Lindahls Kvarg Raspberry",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000023135121",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.049167",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 4
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5926480",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "14",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt Pouch",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000100383827",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Arla Protein",
#             "promoType": "No Promo",
#             "weight": "200g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "8718166007628",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2143",
#             "name": "Arla Protein Strawberry Yogurt Pouch",
# ...
#             "weight": "6x42g     ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5036589254553",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "Yeo Valley Little Yeos Organic No Added Sugar Mango, Vanilla and Blueberry, Banana Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600066"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000376780465",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.0277",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -15
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7050996",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "40",
#             "asdaSuggest": "",
#             "itemName": "Skyr Banana & Peanut Butter Flavour Protein Yoghurt",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000300501537",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Light & Free",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506678",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "2.925",
#             "name": "Light & Free Skyr Banana & Peanut Butter Flavour Protein Yoghurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000300501537",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.025775",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 5
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5033894",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "15",
#             "asdaSuggest": "",
#             "itemName": "Raspberry Yogurt",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001813465",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Arla Protein",
#             "promoType": "No Promo",
#             "weight": "200g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "6413300018035",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.9333",
#             "name": "Arla Protein Raspberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "49100001"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001813465",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.025697",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -3
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Diet, Low Fat & No Added Sugar",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6677300",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "16",
#             "asdaSuggest": "",
#             "itemName": "Skyr Icelandic Style Salted Caramel Flavour Yogurt",
#             "price": "\u00a31.10",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000206330981",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "4025500253707",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3125",
#             "name": "Muller Light Skyr Icelandic Style Salted Caramel Flavour Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000206330981",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.025278",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -2
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7296508",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Pro + Kvarg Banoffee Pie",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000359006880",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Lindahls",
#             "promoType": "No Promo",
#             "weight": "150g      ",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "3023290062777",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.75",
#             "name": "Lindahls Pro + Kvarg Banoffee Pie",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000359006880",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.023591",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -10
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Gut Health",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7461284",
#             "promoDetailFull": "",
#             "availability": "A",
#             "asdaSuggest": "",
#             "itemName": "Gut Health kefir Yogurt British Strawberry",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000383133031",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.75",
#             "brandName": "Biotiful",
#             "promoType": "Rollback",
#             "weight": "350g      ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060337221979",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "0.0",
#             "name": "Biotiful Gut Health kefir Yogurt British Strawberry",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000383133031",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.020826",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -3
#         },
#         {
#             "shelfId": "1215639169975",
#             "shelfName": "Probiotic, Health & Kefir Drinks",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7461286",
#             "promoDetailFull": "",
#             "availability": "A",
#             "asdaSuggest": "",
#             "itemName": "Gut Health Kefir Yogurt Original",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Healthy Yogurt Drinks",
#             "id": "1000383133015",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.75",
#             "brandName": "Biotiful",
#             "promoType": "Rollback",
#             "weight": "350g      ",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060337222143",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "0.0",
#             "name": "Biotiful Gut Health Kefir Yogurt Original",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000383133015",
#             "pricePerUOM": "",
#             "searchTuningScore": "0.019865",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": -1
#         }
#     ],
#     "facets": [
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Chilled Food",
#             "displayName": "Chilled Food",
#             "itemCount": "377"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Baby, Toddler & Kids",
#             "displayName": "Baby, Toddler & Kids",
#             "itemCount": "17"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Bakery",
#             "displayName": "Bakery",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Free From...",
#             "displayName": "Free From...",
#             "itemCount": "12"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Food Cupboard",
#             "displayName": "Food Cupboard",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Drinks",
#             "displayName": "Drinks",
#             "itemCount": "9"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:World & Local Food",
#             "displayName": "World & Local Food",
#             "itemCount": "5"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Toiletries & Beauty",
#             "displayName": "Toiletries & Beauty",
#             "itemCount": "2"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Meat, Poultry & Fish",
#             "displayName": "Meat, Poultry & Fish",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Pet Food & Accessories",
#             "displayName": "Pet Food & Accessories",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA",
#             "displayName": "ASDA",
#             "itemCount": "60"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller",
#             "displayName": "Muller",
#             "itemCount": "25"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Activia",
#             "displayName": "Activia",
#             "itemCount": "17"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:GU",
#             "displayName": "GU",
#             "itemCount": "16"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Yeo Valley",
#             "displayName": "Yeo Valley",
#             "itemCount": "15"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA Extra Special",
#             "displayName": "ASDA Extra Special",
#             "itemCount": "14"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Lindahls",
#             "displayName": "Lindahls",
#             "itemCount": "14"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Actimel",
#             "displayName": "Actimel",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Cadbury",
#             "displayName": "Cadbury",
#             "itemCount": "11"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Alpro",
#             "displayName": "Alpro",
#             "itemCount": "9"
#         }
#     ],
#     "mediaContent": "",
#     "useKeywordAsIcon": "",
#     "processTime": 83,
#     "statusCode": "0"
# }

# %% [markdown]
# ## 3. JSON (JavaScript Object Notation)
#
# ### What is JSON
# - A lightweight data-interchange format
# - "Self-describing" and easy to understand
# - JSON format is text only
# - Language independent: can be read and used as a data format by any programming language
#
# ###  JSON Syntax Rules
# JSON syntax is derived from JavaScript object notation syntax:
# - Data is in **name/value** pairs separated by commas
# - Curly braces hold objects
# - Square brackets hold arrays
#
# ### A JSON object is:
# - **a dictionary** or
# - a **list of dictionaries**
#
# ### Useful JSON functions
# - dumps: save json object to string
# - dump: save json object to file
# - loads: load from a string in json format
# - load: load from a file in json format

# %%
# Exercise 3.1 API returns a JSON object 

parameters = {'keyword': 'yogurt', 
              'r': 'json'}

r=requests.get('https://groceries.asda.com/api/items/search', params=parameters)

# if the API call returns a successful response
if r.status_code==200:
    result = r.json()
    
    df = pd.DataFrame(result["items"])
    df.head()
# Out:
#          shelfId                       shelfName         deptId  \
# 0  1215286383583                         Corners  1215341888021
# 1  1215286383583                         Corners  1215341888021
# 2  1215286383583                         Corners  1215341888021
# 3  1215286383583                         Corners  1215341888021
# 4   910000977060  Diet, Low Fat & No Added Sugar  1215341888021
#
#              deptName isBundle  meatStickerDetails extraLargeImageURL  \
# 0  Yogurts & Desserts    false  10::for::£4::false
# 1  Yogurts & Desserts    false  10::for::£4::false
# 2  Yogurts & Desserts    false  10::for::£4::false
# 3  Yogurts & Desserts    false  10::for::£4::false
# 4  Yogurts & Desserts    false  10::for::£4::false
#
#   bundledItemCount                          scene7Host      cin  ...  \
# 0                0  https://ui.assets-asda.com:443/dm/  7368400  ...
# 1                0  https://ui.assets-asda.com:443/dm/  7368402  ...
# 2                0  https://ui.assets-asda.com:443/dm/  7368406  ...
# 3                0  https://ui.assets-asda.com:443/dm/  7368408  ...
# 4                0  https://ui.assets-asda.com:443/dm/  6346362  ...
#
#   avgWeight                                        iconDetails maxQty  \
# 0                                                           {}   10.0
# 1                                                           {}   10.0
# 2                                                           {}   10.0
# 3                                                           {}   10.0
# 4            {'promotionalIcons': ['59600051'], 'informatio...   10.0
#
#   pricePerWt                                         productURL pricePerUOM  \
# 0       Each  https://groceries.asda.com:443/api/items/view?...
# 1       Each  https://groceries.asda.com:443/api/items/view?...
# 2       Each  https://groceries.asda.com:443/api/items/view?...
# 3       Each  https://groceries.asda.com:443/api/items/view?...
# 4       Each  https://groceries.asda.com:443/api/items/view?...
#
#   searchTuningScore onSale salePrice positionChngByMargin
# 0         8717191.0  False                              0
# 1         5447849.0  False                              0
# 2         5098466.0  False                              0
# 3         4553693.5  False                              0
# 4         3162789.0  False                              0
#
# [5 rows x 45 columns]

# %%
# Exercise 3.2. Parse JSON object (a dictionary)

# convert the first 2 items to string
s = json.dumps(result["items"][0:2], indent=4)
print(s)

# load back from a string
items = json.loads(s)
items

# save to file
json.dump(result["items"], open("items.json","w"))

# load back from file
items = json.load(open("items.json","r"))
print("test loaded data\n")
len(items)
items[0]
# Out:
# [
#     {
#         "shelfId": "1215286383583",
#         "shelfName": "Corners",
#         "deptId": "1215341888021",
#         "deptName": "Yogurts & Desserts",
#         "isBundle": "false",
#         "meatStickerDetails": "10::for::\u00a34::false",
#         "extraLargeImageURL": "",
#         "bundledItemCount": "0",
#         "scene7Host": "https://ui.assets-asda.com:443/dm/",
#         "cin": "7368400",
#         "promoDetailFull": "10 for \u00a34",
#         "availability": "A",
#         "totalReviewCount": "14",
#         "asdaSuggest": "",
#         "itemName": "Corner Vanilla Yogurt with Chocolate Balls",
#         "price": "\u00a30.60",
#         "imageURL": "",
#         "aisleName": "Yogurts & Fromage Frais",
#         "id": "1000377031656",
#         "promoId": "ls92280",
#         "isFavourite": "false",
#         "hasAlternates": "false",
#         "wasPrice": "",
#         "brandName": "Muller",
#         "promoType": "No Promo",
#         "weight": "124g      ",
#         "promoOfferTypeCode": "15",
#         "promoQty": "10",
#         "promoValue": "\u00a34",
#         "productAttribute": "",
#         "scene7AssetId": "4025500277031",
#         "promoDetail": "10 for \u00a34",
#         "bundleDiscount": "0.00",
#         "avgStarRating": "4.6429",
#         "name": "Muller Corner Vanilla Yogurt with Chocolate Balls",
#         "avgWeight": "",
#         "iconDetails": {},
#         "maxQty": "10.0",
#         "pricePerWt": "Each",
#         "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031656",
#         "pricePerUOM": "",
#         "searchTuningScore": "8717191.0",
#         "onSale": false,
#         "salePrice": "",
#         "positionChngByMargin": 0
#     },
#     {
#         "shelfId": "1215286383583",
#         "shelfName": "Corners",
#         "deptId": "1215341888021",
#         "deptName": "Yogurts & Desserts",
#         "isBundle": "false",
#         "meatStickerDetails": "10::for::\u00a34::false",
#         "extraLargeImageURL": "",
#         "bundledItemCount": "0",
#         "scene7Host": "https://ui.assets-asda.com:443/dm/",
#         "cin": "7368402",
#         "promoDetailFull": "10 for \u00a34",
#         "availability": "A",
#         "totalReviewCount": "9",
#         "asdaSuggest": "",
#         "itemName": "Corner Banana Yogurt with Chocolate Flakes",
#         "price": "\u00a30.60",
#         "imageURL": "",
#         "aisleName": "Yogurts & Fromage Frais",
#         "id": "1000377031660",
#         "promoId": "ls92280",
#         "isFavourite": "false",
#         "hasAlternates": "false",
#         "wasPrice": "",
#         "brandName": "Muller",
#         "promoType": "No Promo",
#         "weight": "124g      ",
#         "promoOfferTypeCode": "15",
#         "promoQty": "10",
#         "promoValue": "\u00a34",
#         "productAttribute": "",
#         "scene7AssetId": "4025500277055",
#         "promoDetail": "10 for \u00a34",
#         "bundleDiscount": "0.00",
#         "avgStarRating": "4.8889",
#         "name": "Muller Corner Banana Yogurt with Chocolate Flakes",
#         "avgWeight": "",
#         "iconDetails": {},
#         "maxQty": "10.0",
#         "pricePerWt": "Each",
#         "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000377031660",
#         "pricePerUOM": "",
#         "searchTuningScore": "5447849.0",
#         "onSale": false,
#         "salePrice": "",
#         "positionChngByMargin": 0
#     }
# ]
# [{'shelfId': '1215286383583',
#   'shelfName': 'Corners',
#   'deptId': '1215341888021',
#   'deptName': 'Yogurts & Desserts',
#   'isBundle': 'false',
#   'meatStickerDetails': '10::for::£4::false',
#   'extraLargeImageURL': '',
#   'bundledItemCount': '0',
#   'scene7Host': 'https://ui.assets-asda.com:443/dm/',
#   'cin': '7368400',
#   'promoDetailFull': '10 for £4',
#   'availability': 'A',
#   'totalReviewCount': '14',
#   'asdaSuggest': '',
#   'itemName': 'Corner Vanilla Yogurt with Chocolate Balls',
#   'price': '£0.60',
#   'imageURL': '',
#   'aisleName': 'Yogurts & Fromage Frais',
#   'id': '1000377031656',
#   'promoId': 'ls92280',
#   'isFavourite': 'false',
#   'hasAlternates': 'false',
#   'wasPrice': '',
#   'brandName': 'Muller',
#   'promoType': 'No Promo',
#   'weight': '124g      ',
#   'promoOfferTypeCode': '15',
#   'promoQty': '10',
#   'promoValue': '£4',
#   'productAttribute': '',
#   'scene7AssetId': '4025500277031',
#   'promoDetail': '10 for £4',
#   'bundleDiscount': '0.00',
#   'avgStarRating': '4.6429',
#   'name': 'Muller Corner Vanilla Yogurt with Chocolate Balls',
#   'avgWeight': '',
#   'iconDetails': {},
#   'maxQty': '10.0',
#   'pricePerWt': 'Each',
#   'productURL': 'https://groceries.asda.com:443/api/items/view?itemid=1000377031656',
#   'pricePerUOM': '',
#   'searchTuningScore': '8717191.0',
#   'onSale': False,
#   'salePrice': '',
#   'positionChngByMargin': 0},
#  {'shelfId': '1215286383583',
#   'shelfName': 'Corners',
#   'deptId': '1215341888021',
#   'deptName': 'Yogurts & Desserts',
#   'isBundle': 'false',
#   'meatStickerDetails': '10::for::£4::false',
#   'extraLargeImageURL': '',
#   'bundledItemCount': '0',
#   'scene7Host': 'https://ui.assets-asda.com:443/dm/',
#   'cin': '7368402',
#   'promoDetailFull': '10 for £4',
#   'availability': 'A',
#   'totalReviewCount': '9',
#   'asdaSuggest': '',
#   'itemName': 'Corner Banana Yogurt with Chocolate Flakes',
#   'price': '£0.60',
#   'imageURL': '',
#   'aisleName': 'Yogurts & Fromage Frais',
#   'id': '1000377031660',
#   'promoId': 'ls92280',
#   'isFavourite': 'false',
#   'hasAlternates': 'false',
#   'wasPrice': '',
#   'brandName': 'Muller',
#   'promoType': 'No Promo',
#   'weight': '124g      ',
#   'promoOfferTypeCode': '15',
#   'promoQty': '10',
#   'promoValue': '£4',
#   'productAttribute': '',
#   'scene7AssetId': '4025500277055',
#   'promoDetail': '10 for £4',
#   'bundleDiscount': '0.00',
#   'avgStarRating': '4.8889',
#   'name': 'Muller Corner Banana Yogurt with Chocolate Flakes',
#   'avgWeight': '',
#   'iconDetails': {},
#   'maxQty': '10.0',
#   'pricePerWt': 'Each',
#   'productURL': 'https://groceries.asda.com:443/api/items/view?itemid=1000377031660',
#   'pricePerUOM': '',
#   'searchTuningScore': '5447849.0',
#   'onSale': False,
#   'salePrice': '',
#   'positionChngByMargin': 0}]
# test loaded data
# 60
# {'shelfId': '1215286383583',
#  'shelfName': 'Corners',
#  'deptId': '1215341888021',
#  'deptName': 'Yogurts & Desserts',
#  'isBundle': 'false',
#  'meatStickerDetails': '10::for::£4::false',
#  'extraLargeImageURL': '',
#  'bundledItemCount': '0',
#  'scene7Host': 'https://ui.assets-asda.com:443/dm/',
#  'cin': '7368400',
#  'promoDetailFull': '10 for £4',
#  'availability': 'A',
#  'totalReviewCount': '14',
#  'asdaSuggest': '',
#  'itemName': 'Corner Vanilla Yogurt with Chocolate Balls',
#  'price': '£0.60',
#  'imageURL': '',
#  'aisleName': 'Yogurts & Fromage Frais',
#  'id': '1000377031656',
#  'promoId': 'ls92280',
#  'isFavourite': 'false',
#  'hasAlternates': 'false',
#  'wasPrice': '',
#  'brandName': 'Muller',
#  'promoType': 'No Promo',
#  'weight': '124g      ',
#  'promoOfferTypeCode': '15',
#  'promoQty': '10',
#  'promoValue': '£4',
#  'productAttribute': '',
#  'scene7AssetId': '4025500277031',
#  'promoDetail': '10 for £4',
#  'bundleDiscount': '0.00',
#  'avgStarRating': '4.6429',
#  'name': 'Muller Corner Vanilla Yogurt with Chocolate Balls',
#  'avgWeight': '',
#  'iconDetails': {},
#  'maxQty': '10.0',
#  'pricePerWt': 'Each',
#  'productURL': 'https://groceries.asda.com:443/api/items/view?itemid=1000377031656',
#  'pricePerUOM': '',
#  'searchTuningScore': '8717191.0',
#  'onSale': False,
#  'salePrice': '',
#  'positionChngByMargin': 0}

# %% [markdown]
# ## 4. Get Tweets
#
# Reference:
# - https://github.com/scalto/snscrape-by-location/blob/main/snscrape_by_location_tutorial.ipynb
# - https://medium.com/swlh/how-to-scrape-tweets-by-location-in-python-using-snscrape-8c870fa6ec25
#
# Note: User object is not exposed by TwitterSearchScraper any more.

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
#  search by keywords + time
# TwitterSearchScraper returns an interator, islice loops through the iterator

df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    '"blockchain + since:2021-12-1 until:2022-1-31"').get_items(), 500))

print(len(df))
df.head()
# Out:
# 500
#                                                  url  \
# 0  https://twitter.com/CryptoAnomalous/status/148...
# 1  https://twitter.com/gerard_dache/status/148793...
# 2  https://twitter.com/Rekttrading8/status/148793...
# 3  https://twitter.com/KeanuBelieves/status/14879...
# 4  https://twitter.com/duynguy40664441/status/148...
#
#                        date  \
# 0 2022-01-30 23:59:59+00:00
# 1 2022-01-30 23:59:55+00:00
# 2 2022-01-30 23:59:54+00:00
# 3 2022-01-30 23:59:50+00:00
# 4 2022-01-30 23:59:35+00:00
#
#                                              content  \
# 0  @BradSherman do not get in the way of US techn...
# 1  Congrats to Bill Rockwood Jr, Esq., MBA, J.D.,...
# 2  @kararesurrect You are still announcing it on ...
# 3  @WatcherGuru @AffinityBSC. Being listing on a ...
# 4                         @mine_blockchain scam mnet
#
#                                      renderedContent                   id  \
# 0  @BradSherman do not get in the way of US techn...  1487938677535907845
# 1  Congrats to Bill Rockwood Jr, Esq., MBA, J.D.,...  1487938658023919619
# 2  @kararesurrect You are still announcing it on ...  1487938655159140353
# 3  @WatcherGuru @AffinityBSC. Being listing on a ...  1487938639820693508
# 4                         @mine_blockchain scam mnet  1487938575937126400
#
#                                                 user  replyCount  \
# 0  {'username': 'CryptoAnomalous', 'id': 53283913...           0
# 1  {'username': 'gerard_dache', 'id': 256189693, ...           0
# 2  {'username': 'Rekttrading8', 'id': 14337294741...           0
# 3  {'username': 'KeanuBelieves', 'id': 1425210713...           0
# 4  {'username': 'duynguy40664441', 'id': 14595808...           1
#
#    retweetCount  likeCount  quoteCount  ...  media retweetedTweet quotedTweet  \
# 0             0          0           0  ...   None           None        None
# 1             0          7           3  ...   None           None        None
# 2             0          0           0  ...   None           None        None
# 3             0          1           0  ...   None           None        None
# 4             0          0           0  ...   None           None        None
#
#   inReplyToTweetId                                      inReplyToUser  \
# 0              NaN                                               None
# 1              NaN                                               None
# 2     1.487820e+18  {'username': 'TraderZetas', 'id': 147446459766...
# 3     1.487907e+18  {'username': 'WatcherGuru', 'id': 138749787175...
# 4     1.486773e+18  {'username': 'mine_blockchain', 'id': 13995421...
#
#                                       mentionedUsers coordinates place  \
# 0  [{'username': 'BradSherman', 'id': 30216513, '...        None  None
# 1                                               None        None  None
# 2                                               None        None  None
# 3  [{'username': 'WatcherGuru', 'id': 13874978717...        None  None
# 4  [{'username': 'mine_blockchain', 'id': 1399542...        None  None
#
#   hashtags cashtags
# 0     None     None
# 1     None     None
# 2     None     None
# 3  [ADAPT]     None
# 4     None     None
#
# [5 rows x 27 columns]

# %%
df.content[0:20]
# Out:
# 0     @BradSherman do not get in the way of US techn...
# 1     Congrats to Bill Rockwood Jr, Esq., MBA, J.D.,...
# 2     @kararesurrect You are still announcing it on ...
# 3     @WatcherGuru @AffinityBSC. Being listing on a ...
# 4                            @mine_blockchain scam mnet
# 5     46150 Well, who would have thought that? Minin...
# 6     👋 Hey! Wait! help me, help you, help us? Who's...
# 7     🐳 #Cardano $ADA Whale ❤️laced!\n💰 Transaction ...
# 8     @TheVunderkind I still think we are yet to app...
# 9     63208 Well, who would have thought that? Minin...
# 10    @NathanielBandy1 Nintendo has a hard time putt...
# 11    Love my #Straybears, the art work, the team, t...
# 12    39313 Well, who would have thought that? Minin...
# 13    Asian Company Uses Blockchain Technology to Pr...
# 14                         blockchain the piece of wood
# 15    📢 Crypto Market Status 📢  \n\n$GALA is trading...
# 16    Requesting $FTM funds from the #Stakely Faucet...
# 17    Blockchain and crypto are broken | Opinion htt...
# 18    @MrNodefi Thought about this before, and not s...
# 19    @WiLSONSACCOUNT Saw blockchain topic on TED\nW...
# Name: content, dtype: object

# %%
# search by user

df = pd.DataFrame(itertools.islice(sntwitter.TwitterUserScraper(
    '"zawphyowai199"').get_items(), 500))

print(len(df))
df.tail()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Jerry Chan\Desktop\BIA 660\Web Scraping\Web_Scrapting_III_API_post.ipynb Cell 14 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20Chan/Desktop/BIA%20660/Web%20Scraping/Web_Scrapting_III_API_post.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> # search by user
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20Chan/Desktop/BIA%20660/Web%20Scraping/Web_Scrapting_III_API_post.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> df = pd.DataFrame(itertools.islice(sntwitter.TwitterUserScraper(
#       <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20Chan/Desktop/BIA%20660/Web%20Scraping/Web_Scrapting_III_API_post.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a>     '"zawphyowai199"').get_items(), 500))
#       <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20Chan/Desktop/BIA%20660/Web%20Scraping/Web_Scrapting_III_API_post.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> print(len(df))
#       <a href='vscode-notebook-cell:/c%3A/Users/Jerry%20Chan/Desktop/BIA%20660/Web%20Scraping/Web_Scrapting_III_API_post.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> df.tail()
#
# File c:\anaconda\lib\site-packages\snscrape\modules\twitter.py:699, in TwitterUserScraper.__init__(self, username, isUserId, **kwargs)
#     697 def __init__(self, username, isUserId = False, **kwargs):
#     698 	if not self.is_valid_username(username):
# --> 699 		raise ValueError('Invalid username')
#     700 	super().__init__(f'from:{username}', **kwargs)
#     701 	self._username = username
#
# ValueError: Invalid username

# %% [markdown]
# ## 5. Tweepy
# - Tweepy is a python library to access Twitter API.
# - `pip install tweepy`
# - The Tweepy documentation has detailed explanations: https://docs.tweepy.org/en/stable/
# - You need to apply for a developer account from here: https://developer.twitter.com/en/apply-for-access

# %%
import tweepy
import csv
import datetime

# https://docs.tweepy.org/en/stable/auth_tutorial.html

CONSUMER_KEY=''
CONSUMER_SECRET=''
ACCESS_KEY=''
ACCESS_SECRET=''

auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
auth.set_access_token(ACCESS_KEY,ACCESS_SECRET)
api=tweepy.API(auth)

# %%
# Take a look at the public tweets from your account's home timeline 

public_tweets = api.home_timeline()
print(len(public_tweets))
for tweet in public_tweets[:2]:
    print(tweet.text)
# Out:
# 20
# ICYMI: Crypto miners are feeling the pinch as data shows global revenue from mining has dropped to just over $17 mi… https://t.co/q3pM4tQsYE
# Authorities are responding to Long Beach where an officer-involved shooting has occurred. https://t.co/ArIHkRfhxA

# %%
# is this useful information?
# Let's take a close look at ONE tweet json

public_tweets[1]
# there's no way to figure this out
# Out:
# Status(_api=<tweepy.api.API object at 0x7ff0b86befd0>, _json={'created_at': 'Sun Oct 02 19:04:42 +0000 2022', 'id': 1576649394228805632, 'id_str': '1576649394228805632', 'text': 'Authorities are responding to Long Beach where an officer-involved shooting has occurred. https://t.co/ArIHkRfhxA', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/ArIHkRfhxA', 'expanded_url': 'https://www.cbsnews.com/losangeles/news/police-probe-officer-involved-shooting-in-long-beach/', 'display_url': 'cbsnews.com/losangeles/new…', 'indices': [90, 113]}]}, 'source': '<a href="http://www.socialnewsdesk.com" rel="nofollow">SocialNewsDesk</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 24928809, 'id_str': '24928809', 'name': 'CBS Los Angeles', 'screen_name': 'CBSLA', 'location': 'Los Angeles', 'description': 'CBSLA is CBS2 and KCAL9: Local and Breaking News, Sports, Weather and the Best of LA and OC. \nDownload our app for BREAKING NEWS: https://t.co/o9ZZ2kz2F0', 'url': 'https://t.co/wYJzPOh2zU', 'entities': {'url': {'urls': [{'url': 'https://t.co/wYJzPOh2zU', 'expanded_url': 'http://cbsLA.com/', 'display_url': 'cbsLA.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/o9ZZ2kz2F0', 'expanded_url': 'http://apps.cbslocal.com/los-angeles', 'display_url': 'apps.cbslocal.com/los-angeles', 'indices': [130, 153]}]}}, 'protected': False, 'followers_count': 340055, 'friends_count': 2266, 'listed_count': 3654, 'created_at': 'Tue Mar 17 18:40:17 +0000 2009', 'favourites_count': 1632, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 216543, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000033', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/960690815361306625/aAingYfa_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/960690815361306625/aAingYfa_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/24928809/1656361768', 'profile_link_color': '080C4D', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'C9C7C9', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 2, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 10, 2, 19, 4, 42), id=1576649394228805632, id_str='1576649394228805632', text='Authorities are responding to Long Beach where an officer-involved shooting has occurred. https://t.co/ArIHkRfhxA', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/ArIHkRfhxA', 'expanded_url': 'https://www.cbsnews.com/losangeles/news/police-probe-officer-involved-shooting-in-long-beach/', 'display_url': 'cbsnews.com/losangeles/new…', 'indices': [90, 113]}]}, source='SocialNewsDesk', source_url='http://www.socialnewsdesk.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7ff0b86befd0>, _json={'id': 24928809, 'id_str': '24928809', 'name': 'CBS Los Angeles', 'screen_name ...

# %%
# make it look better
# convert to string
json_str = json.dumps(public_tweets[0]._json)

# deserialise string into python object
parsed = json.loads(json_str)


print(json.dumps(parsed, indent=4, sort_keys=True))
# Now we can have a better idea of the clustered relations of the json object
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sun Oct 02 19:05:00 +0000 2022",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1576649466886619141",
#                 "indices": [
#                     117,
#                     140
#                 ],
#                 "url": "https://t.co/q3pM4tQsYE"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 16,
#     "favorited": false,
#     "geo": null,
#     "id": 1576649466886619141,
#     "id_str": "1576649466886619141",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 6,
#     "retweeted": false,
#     "source": "<a href=\"https://studio.twitter.com\" rel=\"nofollow\">Twitter Media Studio</a>",
#     "text": "ICYMI: Crypto miners are feeling the pinch as data shows global revenue from mining has dropped to just over $17 mi\u2026 https://t.co/q3pM4tQsYE",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Tue Mar 20 17:46:05 +0000 2007",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Top and breaking news, pictures and videos from Reuters. For more breaking business news, follow @ReutersBiz.",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "reuters.com",
#                         "expanded_url": "http://www.reuters.com",
#                         "indices": [
#                             0,
#                             22
#                         ],
#                         "url": "http://t.co/BmHxhkm3Mh"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 749,
#         "follow_request_sent": false,
#         "followers_count": 25545454,
#         "following": true,
#         "friends_count": 1238,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 1652541,
#         "id_str": "1652541",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 136015,
#         "location": "Around the world",
#         "name": "Reuters",
#         "notifications": false,
#         "profile_background_color": "444444",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/1652541/1573687397",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1194751949821939712/3VBu4_Sa_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1194751949821939712/3VBu4_Sa_normal.jpg",
#         "profile_link_color": "006F97",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "F5F5F5",
#         "profile_text_color": "000000",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "Reuters",
#         "statuses_count": 916817,
#         "time_zone": null,
#         "translator_type": "regular",
#         "url": "http://t.co/BmHxhkm3Mh",
#         "utc_offset": null,
#         "verified": true,
#         "withheld_in_countries": []
#     }
# }

# %% [markdown]
# ### 5.1. Get tweets from users' timeline
# - Make a Timeline call to retrieve the most recent 3200 tweets by a user (a rule set by Twitter).
#     - Note: the time range you get depends on how often the user posts tweets.
# - Parameters for the timeline call
#     - `count`: the number of results to try and retrieve per page. Maximum is 200.
#     - Make multiple calls to retrieve the 3200 tweets.
#     - `tweet_mode`:swaps the text index for full_text, and prevents a primary tweet longer than 140 characters from being truncated.
# - Variables of tweet objects
#     - https://docs.tweepy.org/en/stable/api.html#tweepy-api-twitter-api-wrapper

# %%
# Get the first five tweets of a user.
timeline = api.user_timeline(screen_name="KelloggCompany",count=5,tweet_mode="extended")

for status in timeline:
    print (status.id)
    print (status.full_text)
# Out:
# 1575885449150795777
# Our thoughts are with the people impacted by Hurricanes #Fiona + #Ian. To support victims + relief workers, Kellogg is donating more &gt;665,000 servings of cereal + snacks. You can help by donating to https://t.co/0OllBPhjsr or https://t.co/fJC7kLZJrj #betterdays https://t.co/zvawEgRPGl
# 1575826863754182665
# We are extremely honored to be included among the world’s sustainability top-performing companies in the Dow Jones Sustainability Index. Read more: https://t.co/xvlXaEYdYv #DJSI #ESG #BetterDays https://t.co/gH0YyzRzLq
# 1575474217235136512
# Kellogg is proud to have partnered with @FoodBanking for 15+  years to help local food banks #FillTheBlanks in solutions to climate change &amp; #hunger and create #betterdays for those in need.
# How will you help #FillTheBlanks? Learn more: https://t.co/i1UQIHL7Rf
# #FLWDay #IDAFLW https://t.co/sRodNWBfBX
# 1575221387832090625
# Kellogg’s #WIC cereals provide iron, folic acid, vitamin D, and more. And cereal is often enjoyed with milk &amp; fruit, boosting fiber, calcium &amp; protein. Learn more: https://t.co/ovUenECvsr #WHConfHungerHealth #BetterDays https://t.co/VqsFCn16Nz
# 1575221380118851584
# In 2021, our cereals reached 1.3M families through #WIC . Our @whitehouse #WHConfHungerHealth pledge is to do even more next year. Learn more: https://t.co/ovUenECvsr #BetterDays https://t.co/Ukz6vD7Hbr

# %%
# Step 1: get a list of tweets 
# Step 2: extract the varaibles you want

def get_all_tweets(user_name):
    auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
    auth.set_access_token(ACCESS_KEY,ACCESS_SECRET)
    api=tweepy.API(auth)
    
    # initialize the first call
    alltweets=[]
    new_tweets=api.user_timeline(screen_name=user_name, count=200)
    alltweets.extend(new_tweets)
    oldest=alltweets[-1].id-1  #next time start from the oldest one minus one 
    
    # continue to get tweets
    while len(new_tweets)>0:  
        print ("getting tweets before", oldest)
        new_tweets = api.user_timeline(screen_name=user_name,count=200, max_id=oldest)
        alltweets.extend(new_tweets)
        oldest=alltweets[-1].id-1
        print("...{} tweets downloaded so far".format(len(alltweets)))
    
    # extract the variables you want
    outtweets = [[tweet.id_str, tweet.user.name, tweet.created_at, tweet.user.followers_count,
                  tweet.text.encode("utf-8")] for tweet in alltweets]
            
    # write out your variables
    with open('%s_tweet.csv' % user_name,'w') as outputfile: 
        writer=csv.writer(outputfile)
        writer.writerow(["id","user_name","created_at","followers","text"])
        writer.writerows(outtweets)
    pass

# use your function
if __name__ == '__main__':
    #pass in the username of the account you want to download
    get_all_tweets("KelloggCompany")
# Out:
# getting tweets before 1433127895623417857
# ...400 tweets downloaded so far
# getting tweets before 1368699367109038085
# ...600 tweets downloaded so far
# getting tweets before 1306220294751891455
# ...800 tweets downloaded so far
# getting tweets before 1229863740306227199
# ...1000 tweets downloaded so far
# getting tweets before 1164539938920177673
# ...1200 tweets downloaded so far
# getting tweets before 1092430104154775551
# ...1400 tweets downloaded so far
# getting tweets before 1001825648426602497
# ...1600 tweets downloaded so far
# getting tweets before 927505873689300991
# ...1800 tweets downloaded so far
# getting tweets before 868083017285324801
# ...2000 tweets downloaded so far
# getting tweets before 798641013451538431
# ...2200 tweets downloaded so far
# getting tweets before 749265326081249279
# ...2397 tweets downloaded so far
# getting tweets before 703294718990532607
# ...2595 tweets downloaded so far
# getting tweets before 656849723526115327
# ...2794 tweets downloaded so far
# getting tweets before 591317091527057410
# ...2994 tweets downloaded so far
# getting tweets before 525016501406150657
# ...3190 tweets downloaded so far
# getting tweets before 449229452619579391
# ...3240 tweets downloaded so far
# getting tweets before 390564260956229631
# ...3240 tweets downloaded so far

# %%
# Take a look at the table you got
df= pd.read_csv('KelloggCompany_tweet.csv', header=0)
df.head()

# how many tweets we get?
len(df)

# The following tweet is a retweet. Take a look at the text.
# The index of this retweet is based on the table generated previously
# if you run at a different time, you will see a differet tweet
# try to find a retweet and compare the text with the actual tweet
# You can find each tweet on Twitter by its ID.
df.text[34]
# Out:
#                     id        user_name           created_at  followers  \
# 0  1575885449150795777  Kellogg Company  2022-09-30 16:29:04      77625
# 1  1575826863754182665  Kellogg Company  2022-09-30 12:36:16      77625
# 2  1575474217235136512  Kellogg Company  2022-09-29 13:14:58      77625
# 3  1575221387832090625  Kellogg Company  2022-09-28 20:30:19      77625
# 4  1575221380118851584  Kellogg Company  2022-09-28 20:30:17      77625
#
#                                                 text
# 0  b'Our thoughts are with the people impacted by...
# 1  b'We are extremely honored to be included amon...
# 2  b'Kellogg is proud to have partnered with @Foo...
# 3  b'Kellogg\xe2\x80\x99s #WIC cereals provide ir...
# 4  b'In 2021, our cereals reached 1.3M families t...
# 3240
# "b'Our hearts are with the flooding victims in Kentucky and Missouri. We are donating nearly 450,000 servings of snack\\xe2\\x80\\xa6 https://t.co/pm9QC2Pfik'"

# %% [markdown]
# ### 5.2. Deal with truncated text
# - For text mining on Twitter, it is important to get the full text.
#     - Full text would be essential for topic modeling and sentiment analysis.
#     - Full text is also important for extracting mention networks (note the previous example).
# - Use the `tweet_mode="extended"` when calling a user's timeline.
#     - When using extended mode, the `text` attribute of Status objects returned is replaced by a `full_text` attribute, which contains the entire untruncated text of the Tweet.
# - Full text for tweets that are retweets.
#     - If the tweet is a retweet, the full_text is still truncated.
#     - We need to access the full text through `retweeted_status` attribute, which is a status object itself.
# - For reference: https://docs.tweepy.org/en/stable/extended_tweets.html

# %%
# Let's deal with retweets

def get_all_tweets(user_name):
    auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
    auth.set_access_token(ACCESS_KEY,ACCESS_SECRET)
    api=tweepy.API(auth,wait_on_rate_limit=True)

    alltweets=[]
    new_tweets=api.user_timeline(user_name, count=200,tweet_mode="extended")
    alltweets.extend(new_tweets)
    oldest=alltweets[-1].id-1  
    
    # set date condition
    startDate=datetime.datetime(2021, 1, 1, 0, 0, 0)
    while new_tweets[-1].created_at > startDate:
        print ("getting tweets before", oldest)
        new_tweets = api.user_timeline(user_name,count=200, max_id=oldest)
        alltweets.extend(new_tweets)
        oldest=alltweets[-1].id-1
        print("...{} tweets downloaded so far".format(len(alltweets)))
        
    # check if it's a retweet
    # When using extended mode with a Retweet, the full_text attribute of the Status object may be truncated    
    # However, since the retweeted_status attribute (of a Status object that is a Retweet) is itself a Status object
    # the full_text attribute of the Retweeted Status object can be used instead.
    
    outtweets_all=[]
    for tweet in alltweets:
        status = api.get_status(tweet.id, tweet_mode="extended")
        
        if hasattr(status, "retweeted_status"):  # is a retweet
            full_text=status.retweeted_status.full_text.encode("utf-8")
            
            outtweets=[
            # tweet content
            tweet.id_str, tweet.created_at,full_text,
            # user features
            tweet.user.name, tweet.user.screen_name, tweet.user.followers_count, 
            # retweet features
            tweet.retweeted_status.user.name,tweet.retweeted_status.user.screen_name,tweet.retweeted_status.user.description]
            outtweets_all.append(outtweets)
  
        else: # not a retweet
            full_text=status.full_text.encode("utf-8")
                    
            outtweets=[
            # tweet content
            tweet.id_str, tweet.created_at,full_text,
            # user features
            tweet.user.name, tweet.user.screen_name, tweet.user.followers_count, 
            # retweet features
            "no value","no value","no value"]
            outtweets_all.append(outtweets)

    with open('%s_full_tweet.csv' % user_name,'w') as outputfile: 
        writer=csv.writer(outputfile)
        writer.writerow(["id","created_at","full_text",
                        "user.name","user.screen_name","user.followers_count",
                        "retweeted_status.user.name","retweeted_status.user.screen_name","retweeted_status.user.description"])
        writer.writerows(outtweets_all)

        
if __name__ == '__main__':
    #pass in the username of the account you want to download
    get_all_tweets("KelloggCompany")
# Out:
# getting tweets before 1433127895623417857
# ...400 tweets downloaded so far
# getting tweets before 1368699367109038085
# ...600 tweets downloaded so far

# %%
df= pd.read_csv('KelloggCompany_full_tweet.csv', header=0)
df.head()
len(df)
# plese compare this full text with the above truncated text, what differences can you find?
df.full_text[34]
# Out:
#                     id           created_at  \
# 0  1575885449150795777  2022-09-30 16:29:04
# 1  1575826863754182665  2022-09-30 12:36:16
# 2  1575474217235136512  2022-09-29 13:14:58
# 3  1575221387832090625  2022-09-28 20:30:19
# 4  1575221380118851584  2022-09-28 20:30:17
#
#                                            full_text        user.name  \
# 0  b'Our thoughts are with the people impacted by...  Kellogg Company
# 1  b'We are extremely honored to be included amon...  Kellogg Company
# 2  b'Kellogg is proud to have partnered with @Foo...  Kellogg Company
# 3  b'Kellogg\xe2\x80\x99s #WIC cereals provide ir...  Kellogg Company
# 4  b'In 2021, our cereals reached 1.3M families t...  Kellogg Company
#
#   user.screen_name  user.followers_count retweeted_status.user.name  \
# 0   KelloggCompany                 77625                   no value
# 1   KelloggCompany                 77625                   no value
# 2   KelloggCompany                 77625                   no value
# 3   KelloggCompany                 77625                   no value
# 4   KelloggCompany                 77625                   no value
#
#   retweeted_status.user.screen_name retweeted_status.user.description
# 0                          no value                          no value
# 1                          no value                          no value
# 2                          no value                          no value
# 3                          no value                          no value
# 4                          no value                          no value
# 600
# "b'Our hearts are with the flooding victims in Kentucky and Missouri. We are donating nearly 450,000 servings of snacks to help feed victims and relief workers. Visit https://t.co/ASoo3mAWvM to help.  #betterdays https://t.co/uBMpkcGOUH'"

# %% [markdown]
# ### 5.3. Build Twitter networks
# - **Follower-followee network**
#     - If you have a list of user accounts, you may retrive the pairwise boolean values of following relations.
#     - Parameters
#         * `source_id` – The user_id of the subject user.
#         * `source_screen_name` – The screen_name of the subject user.
#         * `target_id` – The user_id of the target user.
#         * `target_screen_name` – The screen_name of the target user.
# - **Retweet network**
#     - Retweeted accounts can be extracted while scraping the API.
#     - Or retweeted accounts can be extracted from the text.
# - **Mention network**
#     - Can be extracted from the full text.

# %%
# How to scrape the follower-followee network?
# we can directly retrieve a bollean value 

dog="Microsoft"
cat="Oracle"

is_following = api.show_friendship(source_screen_name=cat,target_screen_name=dog)
print(is_following[1].following)

# Question: how to get the adjacency matrix of a follower-followee network?
# Out:
# False

# %% [markdown]
# ### 5.4 Keywords search

# %%
# Define the search term and the date_since date as variables
search_words = "blockchain"
date_since = "2021-11-01"

# Collect tweets
tweets = tweepy.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(5)


# Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# RT @MaximusMech: GM!
#
# Winning requires effort... 🤖🪛⚙️
#
# RT, Like and Tag 3 friends for more Mechs!!
#
# #NFTs #NFTCommunity #NFTGiveaway #Meta…
# @toymories are about to take over @octoyber #toymories take over is real with a @ToysForTots_USA collab and staking… https://t.co/VhqSd64KyT
# RT @EnterNFT: This article discusses what a consensus mechanism is, how it works, and the various types available today. Expand your blockc…
# RT @NFAdotcrypto: Why do I hold $XRP? This video should make it clear. 😤🌍🔀🌐#Ripple #Crypto #Blockchain https://t.co/kvPf9BROrH
# RT @NFTMintRadar: 🔥Today's #Ethereum Mints🔥
#
# 🔹@HEXGO_NFT | 0.2 ☰
# 🔹@Ibutsu_nft | 0.029 ☰
# 🔹@888NEKOCLUB | 0.008 ☰
# 🔹@313RabbitNFT | 0.3 ☰
#
# #NF…

# %% [markdown]
# ##### Twitter data resources
# https://github.com/echen102/us-pres-elections-2020 <br>
# https://github.com/echen102/COVID-19-TweetIDs
